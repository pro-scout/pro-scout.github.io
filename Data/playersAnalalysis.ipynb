# %% [markdown]
# This file proposo is to check de data we will be handling

# %%
import pandas as pd

dataSet = pd.read_csv("2021-2022 Football Player Stats.csv",sep=";",encoding='Windows-1252')
dataSet
# Out:
#         Rk              Player Nation   Pos            Squad            Comp
# 0        1          Max Aarons    ENG    DF     Norwich City  Premier League  \
# 1        2    Yunis Abdelhamid    MAR    DF            Reims         Ligue 1
# 2        3   Salis Abdul Samed    GHA    MF    Clermont Foot         Ligue 1
# 3        4     Laurent Abergel    FRA    MF          Lorient         Ligue 1
# 4        5         Charles Abi    FRA    FW  Saint-ï¿½tienne         Ligue 1
# ...    ...                 ...    ...   ...              ...             ...
# 2916  2917  Martï¿½n Zubimendi    ESP    MF    Real Sociedad         La Liga
# 2917  2918    Szymon ?urkowski    POL    MF           Empoli         Serie A
# 2918  2919   Martin ï¿½degaard    NOR    MF          Arsenal  Premier League
# 2919  2920         Milan ?uri?    BIH    FW      Salernitana         Serie A
# 2920  2921       Filip ?uri?i?    SRB  MFFW         Sassuolo         Serie A
#
# ...

# %%
#Players positions
positions = dataSet["Pos"].unique()
positions
for i in positions:
    print(i)
# Out:
# DF
# MF
# FW
# MFFW
# FWMF
# GK
# DFMF
# FWDF
# MFDF
# DFFW
# GKMF

# %%
from random import randint


for i in range(5):
    randomNumber = randint(1,100)
    #print(randomNumber)

    name = dataSet[dataSet['Rk']==randomNumber]
    print(name)

    player_name = dataSet.iat[randomNumber,1]
    print('playerName: '+player_name)
# Out:
#     Rk        Player Nation Pos  Squad     Comp   Age  Born  MP  Starts  ...
# 52  53  Luis Alberto    ESP  MF  Lazio  Serie A  29.0  1992  34      27  ...  \
#
#      Off   Crs  TklW  PKwon  PKcon   OG  Recov  AerWon  AerLost  AerWon%
# 52  0.04  1.92  0.69    0.0    0.0  0.0   7.13    0.42     0.57     42.3
#
# [1 rows x 143 columns]
# playerName: Raï¿½l Albiol
#     Rk           Player Nation Pos      Squad     Comp   Age  Born  MP
# 26  27  Sergio Agï¿½ero    ARG  FW  Barcelona  La Liga  33.0  1988   4  \
#
#     Starts  ...   Off   Crs  TklW  PKwon  PKcon   OG  Recov  AerWon  AerLost
# 26       2  ...  0.59  2.35  0.59    0.0    0.0  0.0   1.76    2.35     1.18  \
#
#     AerWon%
# 26     66.7
#
# [1 rows x 143 columns]
# playerName: Ruben Aguilar
#     Rk Player Nation   Pos     Squad     Comp   Age  Born  MP  Starts  ...
# 80  81  Amath    SEN  FWMF  Mallorca  La Liga  25.0  1996  19       9  ...  \
#
#      Off   Crs  TklW  PKwon  PKcon   OG  Recov  AerWon  AerLost  AerWon%
# ...
